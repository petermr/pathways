# %%
from pathlib import Path
import os
HOME = str(Path.home())
PROJECTS = os.path.join(HOME, "projects")
PROJECT = "open-pathways"
PROJECT_DIR = os.path.join(PROJECTS, PROJECT)
os.chdir(PROJECT_DIR)
os.listdir()
# !tree
# !ami -vv -p . pdfbox
# Out:
# (The console will show DEBUG level messages)
# (Logs will also be printed to /Users/pm286/projects/open-pathways/logs/ami.log)
# Version: ami 2020.08.09_09.54-NEXT-SNAPSHOT
# (jar:file:/Users/pm286/workspace/cmdev/ami3/target/appassembler/repo/ami3-2020.08.09_09.54-NEXT-SNAPSHOT.jar)
# JVM: 14.0.1 (Oracle Corporation Java HotSpot(TM) 64-Bit Server VM 14.0.1+7)
# OS: Mac OS X 10.15.7 x86_64
#
#
# Generic values (AMIPDFTool)
# ...
# input basename      null
# input basename list null
# cproject            /Users/pm286/projects/open-pathways/.
# ctree
# cTreeList           22 trees [./.ipynb_checkpoints, ./PMC2259313, ./PMC2885101,
# excludeBase         {}
# excludeTrees        {}
# forceMake           false
# includeBase         {}
# includeTrees        null
# log4j               {}
# verbose             2
#
# Specific values (AMIPDFTool)
# ...
# Command line options for 'ami pdfbox':
# --debug             : d AMI_BRIEF
# --imagedir          : d pdfimages/
# --maxpages          : d         5
# ...

# %%
os.getcwd()
# !ami -v -p . --inputname raw image

# !ami -vv -p . --inputname raw --output octree image --octree 16 --outputfiles octree channels binary histogram html
# Out:
# (The console will show INFO level messages)
# (Logs will also be printed to /Users/pm286/projects/open-pathways/logs/ami.log)
#
# Generic values (AMIImageTool)
# ...
# input basename      raw
# input basename list null
# cproject
# ctree               /Users/pm286/projects/open-pathways/PMC4503950
# cTreeList           [PMC4503950]
# excludeBase         {}
# excludeTrees        {}
# forceMake           false
# includeBase         {}
# includeTrees        null
# log4j               {}
# verbose             1
#
# Specific values (AMIImageTool)
# ...
# Command line options for 'ami image':
# --borders           : d      null
# --filter            : d     false
# --exclude           : d      null
# --include           : d      null
# --minheight         : d       100
# --minwidth          : d       100
# --annotate          : d     false
# --binarize          : d      null
# --despeckle         : d     false
# --dither            : d      true
# --erodedilate       : d     false
# ...
